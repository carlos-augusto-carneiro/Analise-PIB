# %%
#importação das bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn

# %%
data = pd.read_csv(r'C:\Users\carlo\Downloads\Python data science\FormacaoCD\13.Prática em Python\dados/dados.csv',sep=';')
data.shape
# Out:
# (187, 4)

# %%
data.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
srn.histplot(data.PIB, bins = 10, kde= True, color = 'MediumSpringGreen')
# Out:
# <AxesSubplot:xlabel='PIB', ylabel='Count'>

# %%
srn.histplot(data.VALOREMPENHO, bins = 10, kde = True, color = 'OrangeRed')
# Out:
# <AxesSubplot:xlabel='VALOREMPENHO', ylabel='Count'>

# %%
agrupado1 = data.sort_values('VALOREMPENHO').head(15)
agrupado1 = agrupado1.iloc[:,[1,3]]
agrupado1
agrupado1.plot.bar(x='MUNICIPIO', y= 'VALOREMPENHO', color = 'DeepSkyBlue')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
Agrupado = data.sort_values('PIB').head(15)
Agrupado = Agrupado.iloc[:,1:3]
Agrupado
Agrupado.plot.bar(x='MUNICIPIO', y= 'PIB', color = 'MediumPurple')
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

Agrupado = data.sort_values('PIB').head(15)
Agrupado = Agrupado.iloc[:,1:3]
Agrupado
Agrupado.plot.bar(ax = axes[0,0], x='MUNICIPIO', y= 'PIB', color = 'MediumPurple')
axes[0,1]

agrupado1 = data.sort_values('VALOREMPENHO').head(15)
agrupado1 = agrupado1.iloc[:,[1,3]]
agrupado1
agrupado1.plot.bar(ax = axes[0,1],x='MUNICIPIO', y= 'VALOREMPENHO', color = 'DeepSkyBlue')
axes[0,0]

srn.histplot(data.PIB, bins = 20, kde= True, color = 'MediumSpringGreen', ax =axes[1,0])
axes[1,0]

srn.histplot(data.VALOREMPENHO, bins = 20, kde = True, color = 'OrangeRed', ax = axes[1,1])
axes[1,1]

plt.tight_layout()
plt.show()
